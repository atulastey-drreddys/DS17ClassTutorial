# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = 'https://www.flipkart.com/search?sid=tyy%2C4io&otracker=CLP_Filters&p%5B%5D=facets.price_range.from%3D15000&p%5B%5D=facets.price_range.to%3DMax'

response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html.parser')

soup
# Out:
# <!DOCTYPE html>
# ...

# %%
Box = soup.find_all('div',class_ = 'tUxRFH')
#Box

# %%
product_name = []
storage_info = []
Camera_info = []
Battery_info = []
Warranty_year = []
Price  = []

for i in soup:
    product = Box.find('div',class_ = "KzDlHZ")
    storage = Box.find("li",class_ = "J+igdf")
    Camera = Box.find('li',class_ = 'J+igdf')
    Battery = Box.find('li',class_ = 'J+igdf')
    Warranty = Box.find('li',class_ = 'J+igdf')
    Camera = Box.find('li',class_ = 'J+igdf')
    Price = Box.find('div',class_ = "Nx9bqj CxhGGd")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       6 Price  = []
#       8 for i in soup:
# ----> 9     product = Box.find('div',class_ = "KzDlHZ")
#      10     storage = Box.find("li",class_ = "J+igdf")
#      11     Camera = Box.find('li',class_ = 'J+igdf')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\bs4\element.py:2885, in ResultSet.__getattr__(self, key)
#    2883 def __getattr__(self, key: str) -> None:
#    2884     """Raise a helpful exception to explain a common code fix."""
# -> 2885     raise AttributeError(
#    2886         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    2887     )
#
# ...
