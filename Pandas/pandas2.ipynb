# %% [markdown]
# # Data Cleaning

# %% [markdown]
# import pandas as pd
# import numpy as np

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from seaborn import load_dataset
tips = load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.value_counts()
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 5.75        1.00   Female  Yes     Fri   Dinner  2       1
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 7.25        5.15   Male    Yes     Sun   Dinner  2       1
# 7.51        2.00   Male    No      Thur  Lunch   2       1
#                                                         ..
# 45.35       3.50   Male    Yes     Sun   Dinner  3       1
# 48.17       5.00   Male    No      Sun   Dinner  6       1
# 48.27       6.73   Male    No      Sat   Dinner  4       1
# 48.33       9.00   Male    No      Sat   Dinner  4       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Name: count, Length: 243, dtype: int64

# %%
tips.sex.value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,2))
sns.countplot(tips['sex'])
plt.grid()
plt.show()

# %%
tips.sex.value_counts().index
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category', name='sex')

# %%
tips.sex.value_counts().values
# Out:
# array([157,  87])

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips['smoker'].unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
tips['smoker'].nunique()
# Out:
# 2

# %%
dict1 = {"Name":['Atul',"Shiva",None,"Mohan","Laxman","Harry","Sat","Mat"],
         "Age":[np.nan,34,62,42,75,23,54,None],
         "Location":['Indore',None,"Indore","Guna","Guna","Indore","Ujjain","Indore"],
         "Weight":[45.3,np.nan,76.75,None,34.76,87.3,75,34]}
df = pd.DataFrame(dict1)
df
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0     None     NaN
# 2    None  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %%
df.to_csv('C:\\Users\\GrowTech\\Desktop\\Data Science 16\\Pandas\\Performance Dataset\\Grow_data.csv')

# %%
df.to_csv('Dr_reddys_student.csv')

# %%
df.shape
# Out:
# (8, 4)

# %%
drf = pd.read_csv("Dr_reddys_student.csv",index_col="Unnamed: 0")
drf
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2     NaN  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %%
drf = pd.read_csv("Dr_reddys_student.csv")
drf
# Out:
#    Unnamed: 0    Name   Age Location  Weight
# 0           0    Atul   NaN   Indore   45.30
# 1           1   Shiva  34.0      NaN     NaN
# 2           2     NaN  62.0   Indore   76.75
# 3           3   Mohan  42.0     Guna     NaN
# 4           4  Laxman  75.0     Guna   34.76
# 5           5   Harry  23.0   Indore   87.30
# 6           6     Sat  54.0   Ujjain   75.00
# 7           7     Mat   NaN   Indore   34.00

# %%
drf
# Out:
#    Unnamed: 0    Name   Age Location  Weight
# 0           0    Atul   NaN   Indore   45.30
# 1           1   Shiva  34.0      NaN     NaN
# 2           2     NaN  62.0   Indore   76.75
# 3           3   Mohan  42.0     Guna     NaN
# 4           4  Laxman  75.0     Guna   34.76
# 5           5   Harry  23.0   Indore   87.30
# 6           6     Sat  54.0   Ujjain   75.00
# 7           7     Mat   NaN   Indore   34.00

# %%
# drop 

drf.drop('Unnamed: 0',axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
#       1 # drop
# ----> 3 drf.drop('Unnamed: 0',axis=0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
drf.drop('Unnamed: 0',axis=1)
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2     NaN  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %%
drf
# Out:
#    Unnamed: 0    Name   Age Location  Weight
# 0           0    Atul   NaN   Indore   45.30
# 1           1   Shiva  34.0      NaN     NaN
# 2           2     NaN  62.0   Indore   76.75
# 3           3   Mohan  42.0     Guna     NaN
# 4           4  Laxman  75.0     Guna   34.76
# 5           5   Harry  23.0   Indore   87.30
# 6           6     Sat  54.0   Ujjain   75.00
# 7           7     Mat   NaN   Indore   34.00

# %%
new_df = drf.drop('Unnamed: 0',axis=1)
new_df
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2     NaN  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %%
new_df.drop(['Location','Weight'],axis = 1,inplace=True)

# %%
new_df
# Out:
#      Name   Age
# 0    Atul   NaN
# 1   Shiva  34.0
# 2     NaN  62.0
# 3   Mohan  42.0
# 4  Laxman  75.0
# 5   Harry  23.0
# 6     Sat  54.0
# 7     Mat   NaN

# %%
drf
# Out:
#    Unnamed: 0    Name   Age Location  Weight
# 0           0    Atul   NaN   Indore   45.30
# 1           1   Shiva  34.0      NaN     NaN
# 2           2     NaN  62.0   Indore   76.75
# 3           3   Mohan  42.0     Guna     NaN
# 4           4  Laxman  75.0     Guna   34.76
# 5           5   Harry  23.0   Indore   87.30
# 6           6     Sat  54.0   Ujjain   75.00
# 7           7     Mat   NaN   Indore   34.00

# %%
drf.drop('Unnamed: 0',axis=1,inplace=True)

# %%
drf
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2     NaN  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %% [markdown]
# # dropna

# %%
drf.dropna()
# Out:
#      Name   Age Location  Weight
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00

# %%
drf.dropna(axis = 0) # row wise element removing
# Out:
#      Name   Age Location  Weight
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00

# %%
drf.dropna(axis = 1) # row wise element removing
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
drf
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2     NaN  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %% [markdown]
# # fillna

# %%
fill1 = drf.fillna(0)

# %%
fill1
# Out:
#      Name   Age Location  Weight
# 0    Atul   0.0   Indore   45.30
# 1   Shiva  34.0        0    0.00
# 2       0  62.0   Indore   76.75
# 3   Mohan  42.0     Guna    0.00
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   0.0   Indore   34.00

# %%
fill1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      8 non-null      object
#  1   Age       8 non-null      float64
#  2   Location  8 non-null      object
#  3   Weight    8 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 388.0+ bytes

# %%
fill1["Name"].fillna("Jadeja",inplace = True)
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_13736\2482432943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fill1["Name"].fillna("Jadeja",inplace = True)

# %%
fill1
# Out:
#      Name   Age Location  Weight
# 0    Atul   0.0   Indore   45.30
# 1   Shiva  34.0        0    0.00
# 2       0  62.0   Indore   76.75
# 3   Mohan  42.0     Guna    0.00
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   0.0   Indore   34.00

# %%
drf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   Age       6 non-null      float64
#  2   Location  7 non-null      object
#  3   Weight    6 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 388.0+ bytes

# %%
drf
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2     NaN  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %%
drf['Name'].fillna("Jadeja",inplace = True)

# %%
drf
# Out:
#      Name   Age Location  Weight
# 0    Atul   NaN   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2  Jadeja  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat   NaN   Indore   34.00

# %%
drf['Age'].fillna(50,inplace=True)
# Out:
# C:\Users\GrowTech\AppData\Local\Temp\ipykernel_13736\2730443397.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   drf['Age'].fillna(50,inplace=True)

# %%
drf
# Out:
#      Name   Age Location  Weight
# 0    Atul  50.0   Indore   45.30
# 1   Shiva  34.0      NaN     NaN
# 2  Jadeja  62.0   Indore   76.75
# 3   Mohan  42.0     Guna     NaN
# 4  Laxman  75.0     Guna   34.76
# 5   Harry  23.0   Indore   87.30
# 6     Sat  54.0   Ujjain   75.00
# 7     Mat  50.0   Indore   34.00

# %%
drf.describe()
# Out:
#              Age     Weight
# count   8.000000   6.000000
# mean   48.750000  58.851667
# std    16.131159  23.546074
# min    23.000000  34.000000
# 25%    40.000000  37.395000
# 50%    50.000000  60.150000
# 75%    56.000000  76.312500
# max    75.000000  87.300000

# %%
drf['Weight'].mean()
# Out:
# np.float64(58.85166666666667)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
drf['Weight'].fillna(drf['Weight'].mean(),inplace=True)
drf
# Out:
#      Name   Age Location     Weight
# 0    Atul  50.0   Indore  45.300000
# 1   Shiva  34.0      NaN  58.851667
# 2  Jadeja  62.0   Indore  76.750000
# 3   Mohan  42.0     Guna  58.851667
# 4  Laxman  75.0     Guna  34.760000
# 5   Harry  23.0   Indore  87.300000
# 6     Sat  54.0   Ujjain  75.000000
# 7     Mat  50.0   Indore  34.000000

# %%
drf['Location'].mode()[0]
# Out:
# 'Indore'

# %%
drf['Location'].fillna(drf['Location'].mode()[0],inplace=True)
drf
# Out:
#      Name   Age Location     Weight
# 0    Atul  50.0   Indore  45.300000
# 1   Shiva  34.0   Indore  58.851667
# 2  Jadeja  62.0   Indore  76.750000
# 3   Mohan  42.0     Guna  58.851667
# 4  Laxman  75.0     Guna  34.760000
# 5   Harry  23.0   Indore  87.300000
# 6     Sat  54.0   Ujjain  75.000000
# 7     Mat  50.0   Indore  34.000000

# %%
drf.isnull()
# Out:
#     Name    Age  Location  Weight
# 0  False  False     False   False
# 1  False  False     False   False
# 2  False  False     False   False
# 3  False  False     False   False
# 4  False  False     False   False
# 5  False  False     False   False
# 6  False  False     False   False
# 7  False  False     False   False

# %%
drf.isnull().sum()
# Out:
# Name        0
# Age         0
# Location    0
# Weight      0
# dtype: int64

# %% [markdown]
# # Duplicate

# %%
drf.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
drf.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
drf.drop_duplicates(inplace=True)

# %%
drf
# Out:
#      Name   Age Location     Weight
# 0    Atul  50.0   Indore  45.300000
# 1   Shiva  34.0   Indore  58.851667
# 2  Jadeja  62.0   Indore  76.750000
# 3   Mohan  42.0     Guna  58.851667
# 4  Laxman  75.0     Guna  34.760000
# 5   Harry  23.0   Indore  87.300000
# 6     Sat  54.0   Ujjain  75.000000
# 7     Mat  50.0   Indore  34.000000
